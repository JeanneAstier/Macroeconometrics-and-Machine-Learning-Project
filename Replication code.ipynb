# %% [markdown]
# # Packages

# %%
import pandas as pd 
import numpy as np

from sklearn import decomposition, datasets
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # 1. Data
#
# ## 1. a) data from FRED-MD
# "_We use the vintage as of January 2016. Our sample extends from January 1960 to December 2015 (672 observations), and
# only variables with all observations in the sample period are used (122 variables)._"

# %%
# import data from FRED-MD, vintage of January 2016
database = pd.read_csv(r'C:\Users\jeann\Downloads\2016-01.csv', sep=',')

# set correctly the dates
database = database.drop([0])
database.sasdate=pd.to_datetime(database.sasdate)
database = database.rename(columns={"sasdate": "Date"})
database = database.set_index("Date",drop=True)

# keep only dates bewteen Jan 1960 and Dec 2015
database = database.drop(database[database.index < '1960-01-01'].index)
database = database.drop(database[database.index > '2015-12-01'].index)
database
# Out:
#                 RPI  W875RX1  DPCERA3M086SBEA     CMRMTSPLx       RETAILx  \
# Date
# 1960-01-01   2391.2   2252.5           18.910  2.654060e+05   18762.29853
# 1960-02-01   2392.8   2253.6           18.993  2.692650e+05   18831.78085
# 1960-03-01   2397.2   2255.5           19.262  2.617733e+05   18811.03986
# 1960-04-01   2405.6   2263.6           19.560  2.643641e+05   19304.67539
# 1960-05-01   2411.7   2269.4           19.166  2.561738e+05   19016.37565
# ...             ...      ...              ...           ...           ...
# 2015-08-01  14100.5  11661.9          114.403  1.214198e+06  447133.00000
# 2015-09-01  14136.3  11690.1          114.682  1.229777e+06  446855.00000
# 2015-10-01  14189.6  11737.4          114.654  1.228417e+06  446929.00000
# 2015-11-01  14226.0  11767.2          114.994           NaN  448580.00000
# 2015-12-01      NaN      NaN              NaN           NaN  448086.00000
#
#               INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  ...  \
# Date                                                          ...
# 1960-01-01   25.0099   25.2801   24.0998   34.2255   24.5120  ...
# 1960-02-01   24.7873   25.1368   24.0170   33.8357   24.1747  ...
# 1960-03-01   24.5648   25.0508   23.9895   33.8747   23.6968  ...
# 1960-04-01   24.3701   25.1082   24.0170   34.1086   23.6687  ...
# 1960-05-01   24.3422   25.2514   24.1825   34.3035   23.8936  ...
# ...              ...       ...       ...       ...       ...  ...
# 2015-08-01  107.5730  105.3324  105.1660  107.0618  120.8002  ...
# 2015-09-01  107.5507  105.1969  104.8814  107.0055  121.2474  ...
# 2015-10-01  107.3797  105.2874  104.5894  106.7995  122.2536  ...
# 2015-11-01  106.4080  104.6108  103.8916  106.1729  122.3621  ...
# 2015-12-01  106.0222  104.2173  103.3594  105.3688  122.0207  ...
#
#             DSERRG3M086SBEA  CES0600000008  CES2000000008  CES3000000008  \
# Date
# 1960-01-01           12.502           2.22           2.57           2.13
# 1960-02-01           12.522           2.23           2.59           2.14
# 1960-03-01           12.529           2.24           2.69           2.14
# 1960-04-01           12.555           2.24           2.61           2.14
# 1960-05-01           12.590           2.24           2.64           2.14
# ...                     ...            ...            ...            ...
# 2015-08-01          113.196          22.03          25.25          20.00
# 2015-09-01          113.381          21.99          25.02          20.07
# 2015-10-01          113.512          22.13          25.36          20.05
# 2015-11-01          113.750          22.14          25.43          20.06
# 2015-12-01              NaN          22.19          25.46          20.08
#
#             UMCSENTx    MZMSL  DTCOLNVHFNM   DTCTHFNM     INVEST  VXOCLSx
# Date
# 1960-01-01       NaN    286.7      7362.00   14063.00    75.4515      NaN
# 1960-02-01     100.0    287.0      7396.00   14144.00    73.3363      NaN
# 1960-03-01       NaN    287.8      7456.00   14239.00    71.5296      NaN
# 1960-04-01       NaN    288.3      7582.00   14413.00    71.4718      NaN
# 1960-05-01      93.3    289.1      7673.00   14559.00    71.6858      NaN
# ...              ...      ...          ...        ...        ...      ...
# 2015-08-01      91.9  13530.5    338838.14  896818.51  3036.4756  19.8997
# 2015-09-01      87.2  13569.7    343472.98  905935.02  3027.7410  24.4603
# 2015-10-01      90.0  13617.7    343664.35  906420.20  3043.2053  16.5926
# 2015-11-01      91.3  13697.6          NaN        NaN  3067.2225  16.0358
# 2015-12-01      92.6  13729.2          NaN        NaN  3097.6725  18.7364
#
# [672 rows x 135 columns]

# %%
database = database.dropna(axis='columns')

# %% [markdown]
# Problem here: using the data from January 2016 and keeping only columns with no missing observation over the period, I find 113 variables (not 122). Using data from February 2016, I find 127 variables to keep.

# %% [markdown]
# # 1. b) principal components
#
# "_In addition, we include as potential predictors the four principal component factors computed from this set of variables._"

# %%
X = database
std_slc = StandardScaler()
X_std = std_slc.fit_transform(X) # remove the outliners and scale the data (mean zero, standard deviation one)

print(X_std.shape)

pca = decomposition.PCA(n_components=4) # 4 principal component factors

X_std_pca = pca.fit_transform(X_std) # create the principal components

print(X_std_pca.shape)
print(X_std_pca)
# Out:
# (672, 113)
# (672, 4)
# [[-10.62133964  -6.78077911   0.47357959   0.1433929 ]
#  [-10.71868904  -6.00917193   1.33829026   0.57302953]
#  [-10.16783183  -5.30521052   3.76581964   0.91432604]
#  ...
#  [ 14.82304223  -3.96166708   0.12766715   2.73993954]
#  [ 14.72002176  -3.7321304   -0.13056689   2.03511122]
#  [ 14.44502079  -3.76997696   0.03391446   2.01154912]]

# %%
# add these four principal components to the database
pc = X_std_pca.transpose()
database = database.assign(pc1=pc[0], pc2=pc[1], pc3=pc[2], pc4=pc[3])

# %%
database
# Out:
#                  RETAILx    INDPRO   IPFPNSS   IPFINAL   IPCONGD  IPDCONGD  \
# Date
# 1960-01-01   18762.29853   25.0099   25.2801   24.0998   34.2255   24.5120
# 1960-02-01   18831.78085   24.7873   25.1368   24.0170   33.8357   24.1747
# 1960-03-01   18811.03986   24.5648   25.0508   23.9895   33.8747   23.6968
# 1960-04-01   19304.67539   24.3701   25.1082   24.0170   34.1086   23.6687
# 1960-05-01   19016.37565   24.3422   25.2514   24.1825   34.3035   23.8936
# ...                  ...       ...       ...       ...       ...       ...
# 2015-08-01  447133.00000  107.5730  105.3324  105.1660  107.0618  120.8002
# 2015-09-01  446855.00000  107.5507  105.1969  104.8814  107.0055  121.2474
# 2015-10-01  446929.00000  107.3797  105.2874  104.5894  106.7995  122.2536
# 2015-11-01  448580.00000  106.4080  104.6108  103.8916  106.1729  122.3621
# 2015-12-01  448086.00000  106.0222  104.2173  103.3594  105.3688  122.0207
#
#             IPNCONGD   IPBUSEQ     IPMAT    IPDMAT  ...  CUSR0000SA0L5  \
# Date                                                ...
# 1960-01-01   39.0678    9.3444   24.1864   14.8444  ...         29.900
# 1960-02-01   38.6678    9.4050   23.8730   14.5985  ...         30.000
# 1960-03-01   39.0234    9.4252   23.4812   14.1375  ...         30.000
# 1960-04-01   39.4234    9.3242   22.9327   13.6304  ...         30.100
# 1960-05-01   39.5567    9.3545   22.7237   13.4460  ...         30.100
# ...              ...       ...       ...       ...  ...            ...
# 2015-08-01  103.6921  107.4097  110.1133  107.8878  ...        227.855
# 2015-09-01  103.5103  106.8087  110.2453  107.2997  ...        227.443
# 2015-10-01  103.0031  106.3283  109.7203  108.1047  ...        227.802
# 2015-11-01  102.1941  105.3161  108.3548  107.4341  ...        227.804
# 2015-12-01  101.2752  105.3836  107.9811  107.3948  ...        227.513
#
#             CES0600000008  CES2000000008  CES3000000008    MZMSL     INVEST  \
# Date
# 1960-01-01           2.22           2.57           2.13    286.7    75.4515
# 1960-02-01           2.23           2.59           2.14    287.0    73.3363
# 1960-03-01           2.24           2.69           2.14    287.8    71.5296
# 1960-04-01           2.24           2.61           2.14    288.3    71.4718
# 1960-05-01           2.24           2.64           2.14    289.1    71.6858
# ...                   ...            ...            ...      ...        ...
# 2015-08-01          22.03          25.25          20.00  13530.5  3036.4756
# 2015-09-01          21.99          25.02          20.07  13569.7  3027.7410
# 2015-10-01          22.13          25.36          20.05  13617.7  3043.2053
# 2015-11-01          22.14          25.43          20.06  13697.6  3067.2225
# 2015-12-01          22.19          25.46          20.08  13729.2  3097.6725
#
#                   pc1       pc2       pc3       pc4
# Date
# 1960-01-01 -10.621340 -6.780779  0.473580  0.143393
# 1960-02-01 -10.718689 -6.009172  1.338290  0.573030
# 1960-03-01 -10.167832 -5.305211  3.765820  0.914326
# 1960-04-01 -10.360978 -4.891762  3.440928  0.853505
# 1960-05-01 -10.307163 -4.827300  3.632587  0.496258
# ...               ...       ...       ...       ...
# 2015-08-01  14.832774 -3.979578  0.005228  2.672024
# 2015-09-01  14.676713 -3.771285  0.106118  2.504429
# 2015-10-01  14.823042 -3.961667  0.127667  2.739940
# 2015-11-01  14.720022 -3.732130 -0.130567  2.035111
# 2015-12-01  14.445021 -3.769977  0.033914  2.011549
#
# [672 rows x 117 columns]

# %% [markdown]
# "_We consider four lags of all variables, as well as four autoregressive terms. Hence, the analysis contemplates 508 potential predictors._"
#
# i.e. to predict inflation at date t, we use inflation from t-1 to t-5 (4 predictors) as well as all other variables (the 122 original ones + the four principal components) from t-1 to t-5. So in total we have 4+4*(122+4)=508 variables in theory, but we don't have 122 variables (only 113 or 127).
